# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
X = np.random.rand(100, 1)
y  = 4 + 3 * X + np.random.randn(100, 1)

print(X)
# Out:
# [[0.73729319]
#  [0.43965105]
#  [0.01123966]
#  [0.34696607]
#  [0.10255653]
#  [0.62555065]
#  [0.19059813]
#  [0.88203538]
#  [0.14382075]
#  [0.38588736]
#  [0.66101563]
#  [0.33584868]
#  [0.52367299]
#  [0.98928055]
#  [0.16731571]
#  [0.54357032]
#  [0.85394775]
#  [0.50604913]
#  [0.8297755 ]
#  [0.73662761]
#  [0.56277852]
#  [0.54737856]
#  [0.25504679]
#  [0.91106752]
#  [0.92771048]
#  [0.61337522]
#  [0.76931662]
#  [0.46992575]
#  [0.28704582]
#  [0.09243815]
#  [0.38881125]
#  [0.52869605]
#  [0.61463969]
#  [0.53965237]
#  [0.37987668]
#  [0.02245069]
#  [0.98598172]
#  [0.42085036]
#  [0.43613504]
#  [0.28843825]
#  [0.71407526]
#  [0.95000164]
#  [0.95344314]
#  [0.88400134]
#  [0.76434756]
#  [0.77664874]
#  [0.58234813]
#  [0.03591783]
#  [0.27510641]
#  [0.17128852]
#  [0.16562903]
#  [0.03551689]
#  [0.30095636]
#  [0.20462285]
#  [0.24878306]
#  [0.0519829 ]
#  [0.88185614]
#  [0.67794515]
#  [0.88768442]
#  [0.48915186]
#  [0.84157539]
#  [0.18698255]
#  [0.43857614]
#  [0.83454264]
#  [0.52221872]
#  [0.5375254 ]
#  [0.93104028]
#  [0.91234226]
#  [0.67331389]
#  [0.32427424]
#  [0.73413751]
#  [0.45457029]
#  [0.59985421]
#  [0.40476088]
#  [0.58967288]
#  [0.19475197]
#  [0.044781  ]
#  [0.349185  ]
#  [0.44636922]
#  [0.02936871]
#  [0.48394168]
#  [0.95223014]
#  [0.94935051]
#  [0.7226647 ]
#  [0.32942725]
#  [0.04557529]
#  [0.06420551]
#  [0.23127414]
#  [0.85982417]
#  [0.47287243]
#  [0.24426687]
#  [0.84703377]
#  [0.16618101]
#  [0.21179176]
#  [0.01965414]
#  [0.49016097]
#  [0.2534924 ]
#  [0.37553971]
#  [0.56021388]
#  [0.53103985]]

# %%
# plt.scatter(X, y)

X_b = np.c_[np.ones((100,1)), X]
theta = np.linalg.inv(X_b.T.dot(X_b).dot(X_b.T).dot(y))

print(X_b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[82], line 4
#       1 # plt.scatter(X, y)
#       3 X_b = np.c_[np.ones((100,1)), X]
# ----> 4 theta = np.linalg.inv(X_b.dot(X_b).dot(X_b.T).dot(y))
#       7 print(X_b)
#
# ValueError: shapes (100,2) and (100,2) not aligned: 2 (dim 1) != 100 (dim 0)
