# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "animal" : ["Falcon", "Falcon", "Bird", "Bird"],
    "speed" : [120, 150, 20, 30],
})

# print(df.groupby("speed")["speed"].sum())
new_df = df.groupby(["animal"])['speed'].sum()
new_df = pd.DataFrame(new_df)
# Out:
# Index(['animal', 'speed'], dtype='object')
